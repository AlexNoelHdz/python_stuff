# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cadena = "Esto es un texto de ejemplo"
cadena
# Out:
# 'Esto es un texto de ejemplo'

# %%
longitud = len(cadena)
longitud
# Out:
# 27

# %%
str_longitud = str(longitud)
str_longitud
# Out:
# '27'

# %%
type(str_longitud)
# Out:
# str

# %%
mayusculas = cadena.capitalize()
mayusculas
# Out:
# 'Esto es un texto de ejemplo'

# %%
resultado = f"{mayusculas} tiene longitud de {str_longitud}"
resultado
# Out:
# 'Esto es un texto de ejemplo tiene longitud de 27'

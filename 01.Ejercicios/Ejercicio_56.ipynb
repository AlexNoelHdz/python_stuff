# %% [markdown]
# ![image.png](attachment:image.png)

# %%
inicio = 1
fin = 6
while (inicio < fin):
    print("Esta es la fila {0}".format(inicio))
    inicio += 1
# Out:
# Esta es la fila 1
# Esta es la fila 2
# Esta es la fila 3
# Esta es la fila 4
# Esta es la fila 5

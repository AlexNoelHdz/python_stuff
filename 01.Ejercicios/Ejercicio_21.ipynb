# %% [markdown]
# ![image.png](attachment:image.png)

# %%
numero1 = 5
numero1
# Out:
# 5

# %%
numero2 = 8
numero2
# Out:
# 8

# %%
suma = numero1 + numero2
suma
# Out:
# 13

# %%
print(f"El resultado de la suma de {numero1} + {numero2} es {suma}")
# Out:
# El resultado de la suma de 5 + 8 es 13

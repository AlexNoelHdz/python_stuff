# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nota = 4.5
trabajo_realizado = "si"
nota_final = "aprobado" if nota >= 4 and trabajo_realizado == "si" else "suspenso"
print(nota_final)
# Out:
# aprobado

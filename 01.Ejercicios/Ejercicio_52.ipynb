# %% [markdown]
# ![image.png](attachment:image.png)

# %%
frutas = {"manzana":"apple", "naranja":"orange", "platano":"banana", "limon":"lemon"}
print(f"Naranja se traduce: {frutas['naranja']}")
print("========================================")
frutas['piña'] = 'pineapple'
for key, value in frutas.items():
    print(f"{key} se traduce: {value}")
# Out:
# Naranja se traduce: orange
# ========================================
# manzana se traduce: apple
# naranja se traduce: orange
# platano se traduce: banana
# limon se traduce: lemon
# piña se traduce: pineapple

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lista = [1,2,25,33,56,89,43,13,62,24]
numero = 21
respuesta = "si" if numero in lista else "no"
print( f"El número {numero} {respuesta} está en la lista" )
# Out:
# El número 21 no está en la lista

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
minimo = 20
maximo = 500
print("Dame un numero")
dato = input()
numero = int(dato)

if(numero < minimo):
    print("Valor bajo")
    
if(numero > maximo):
    print("Valor alto")
    
if(numero > minimo) and (numero < maximo):
    print("Valor medio")
# Out:
# Dame un numero
# 501
# Valor alto

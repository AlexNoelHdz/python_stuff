# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tupla = ("Antonio","Pedro","Maria")
tupla
print("Ingrese un nombre")
dato = input()
dato_is_in_tupla = "sí" if dato in tupla else "no"
print(f"{dato} {dato_is_in_tupla} está en la tupla")
# Out:
# Ingrese un nombre
# Antonio
# Antonio sí está en la tupla

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nota1 = 6
nota2 = 4
nota3 = 7
nota_media = (nota1 + nota2 + nota3) / 3

# %%
nota_media
# Out:
# 5.666666666666667

# %%
nota_final = "Reprobado"
if( nota_media >= 5):
    nota_final = "Aprobado"

print(nota_final)
# Out:
# Aprobado

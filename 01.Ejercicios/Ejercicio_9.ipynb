# %% [markdown]
# ![image.png](attachment:image.png)

# %%
numero1 = 5
type(numero1)
# Out:
# int

# %%
numero2 = 6.5
type(numero2)
# Out:
# float

# %%
numero3 = 7
type(numero3)
# Out:
# int

# %%
suma = numero1 + numero2 + numero3

# %%
suma
# Out:
# 18.5

# %%
type(suma)
# Out:
# float
